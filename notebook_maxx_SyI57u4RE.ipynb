# %%
import pandas as pd
data=[['Japan',1890,1504 ,35220 ,2.71],
['Brazil' ,1900,779 ,10070 ,2.40],
['Mexico',1900,1159 ,14270,2.35],
['Germany',1870,2184 ,35940 ,2.05],
['Canada',1870,2375 ,36220 ,1.99],
['China' ,1900,716 ,6020 ,1.99],
['United States' ,1870,4007 ,46970 ,1.80],
['Argentina' ,1900,2293 ,14020 ,1.69],
['United Kingdom' ,1870,4808 ,36130 ,1.47],
['India' ,1900,675 ,2960 ,1.38],
['Indonesia' ,1900,891 ,3830 ,1.36],
['Pakistan' ,1900,737 ,2700 ,1.21],
['Bangladesh' ,1900,623 ,1440,0.78]] 
df = pd.DataFrame(data,columns=['Country','Period','Real GDP per Person at Beginning of Period','Real GDP per Person at End of Period','Annualized Growth Rate'])
print(df.head())
# Out:
#    Country  Period  Real GDP per Person at Beginning of Period  \
# 0    Japan    1890                                        1504
# 1   Brazil    1900                                         779
# 2   Mexico    1900                                        1159
# 3  Germany    1870                                        2184
# 4   Canada    1870                                        2375
#
#    Real GDP per Person at End of Period  Annualized Growth Rate
# 0                                 35220                    2.71
# 1                                 10070                    2.40
# 2                                 14270                    2.35
# 3                                 35940                    2.05
# 4                                 36220                    1.99

# %%
import pandas as pd
unemployment_data=[
['Australia',5.008],
['Austria',4.693],
['Belgium',5.658],
['Canada',5.800],
['Chile',6.877],
['Colombia',10.436],
['Czech Republic',2.085],
['Denmark',5.089],
['Estonia',4.487],
['Euro area',7.901],
['European Union',6.597],
['Finland',6.628],
['France',8.831],
['Germany',3.272],
['Greece',18.362],
['Hungary',3.690],
['Iceland',2.666],
['Ireland',5.519],
['Israel',4.076],
['ItalLithuania',5.994],
['Japan',2.433],
['Korea',3.967],
['Latvia',6.866]]
df =pd.DataFrame(unemployment_data,columns=['country','unemployment_rate'])
print(df.head())
df1 = df[df['unemployment_rate'] > 8.5]
print(df1)
# Out:
#      country  unemployment_rate
# 0  Australia              5.008
# 1    Austria              4.693
# 2    Belgium              5.658
# 3     Canada              5.800
# 4      Chile              6.877
#      country  unemployment_rate
# 5   Colombia             10.436
# 12    France              8.831
# 14    Greece             18.362
